# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
print(int_words[:100])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580, 0, 194, 10, 190, 58, 4, 5, 10712, 214, 6, 1324, 104, 454, 19, 58, 2731, 362, 6, 3672, 0, 708, 1, 371, 26, 40, 36, 53, 539, 97, 11, 5, 1423, 2757, 18, 567, 686, 7088, 0, 247, 5233, 10, 1052, 27, 0, 320, 248, 44611, 2877, 792, 186, 5233, 11, 5, 200, 602, 10, 0, 1134, 19, 2621, 25, 8983, 2, 279, 31, 4147, 141, 59, 25, 6437]

# %%
## Your code here
from collections import Counter
words_counter = Counter(int_words)
total_wordcount = len(int_words)
discarding_threshold = 0.00001
p_discard = Counter()
for word, count in words_counter.most_common():
    frequency = count / total_wordcount
    p_discard[word] = 1 - np.sqrt(discarding_threshold / frequency)

train_words = []
for word in int_words:
    if np.random.random_sample() > p_discard[word]:
        train_words.append(word)
print(len(train_words))
# Out:
# 4627932

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    offset = np.random.randint(1, window_size+1)
    start = max(0, idx - offset)
    end = min(len(words), idx + offset)
    target_words = set(words[start:idx] + words[idx+1:end])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6303 0.0559 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5849 0.0570 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5014 0.0570 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5957 0.0576 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5259 0.0578 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5530 0.0576 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5494 0.0575 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5692 0.0575 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4894 0.0574 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4519 0.0572 sec/batch
# Nearest to history: spencer, unimpressed, brennan, regulate, alton, colony, cataloging, centralizing,
# Nearest to that: gotland, juba, candidates, fashions, massilia, usurpers, power, commercially,
# Nearest to has: scraped, jellicoe, pleaded, emilia, claude, shirts, afterglow, atmosphere,
# Nearest to seven: caesarea, panspermia, notions, david, khanate, republica, autocorrelation, waylon,
# Nearest to other: subtypes, upload, repent, mark, invulnerable, neberg, inmarsat, multifinder,
# Nearest to many: zarqawi, parker, hyginus, struct, hizballah, matsushita, classicists, suppositions,
# Nearest to up: reminders, seaports, dur, ehrlich, zinc, janusz, rhoades, deems,
# Nearest to four: tiff, abensberg, km, swapping, rulebooks, snoopy, extension, malcolm,
# Nearest to older: enciphered, affords, severus, schacht, emergency, seriously, escu, jihad,
# Nearest to bill: bumblebee, monument, edgbaston, hummingbird, kashmir, drums, rated, bovine,
# Nearest to engine: workspace, carotid, ennobled, guttural, glenfinnan, hangul, corps, dealers,
# Nearest to test: armpit, vocabulary, obstetricians, satchel, wladislaus, todd, encomium, leonhard,
# Nearest to egypt: rhotic, galton, fold, missing, cantilever, private, superset, greenfield,
# Nearest to operating: tabernacles, underpinnings, conurbations, resisters, pater, ensured, talbot, fac,
# Nearest to http: alberta, possessions, angering, zcoa, percieved, stimson, commandants, dismay,
# Nearest to ocean: soloists, uncertainties, opulence, verdun, gauntlets, xiong, cleaned, medicated,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4863 0.0591 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4026 0.0584 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3318 0.0583 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2511 0.0581 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2121 0.0583 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1870 0.0587 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1414 0.0588 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0942 0.0585 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0266 0.0579 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0168 0.0576 sec/batch
# Nearest to history: regulate, since, colony, brennan, spencer, cataloging, drops, reason,
# Nearest to that: for, candidates, juba, power, commercially, gotland, sounds, practice,
# Nearest to has: scraped, atmosphere, jellicoe, museum, shirts, pictures, claude, pleaded,
# Nearest to seven: david, republica, notions, d, caesarea, panspermia, origin, surrounding,
# Nearest to other: mark, subtypes, repent, mosquito, upload, sixteen, substantiate, passed,
# Nearest to many: zarqawi, parker, central, meant, abuse, institutions, missing, done,
# Nearest to up: seaports, acquired, reminders, zinc, dur, endogenous, ehrlich, reports,
# Nearest to four: extension, km, tiff, detected, presented, abensberg, malcolm, contour,
# Nearest to older: enciphered, emergency, seriously, occurred, severus, trace, affords, schacht,
# Nearest to bill: bumblebee, monument, drums, rated, polished, kilograms, hummingbird, kashmir,
# Nearest to engine: workspace, ennobled, corps, guttural, carotid, dealers, pulley, baptismal,
# Nearest to test: armpit, obstetricians, vocabulary, wladislaus, satchel, binswanger, venue, emmy,
# Nearest to egypt: rhotic, private, missing, fold, greenfield, superset, galton, cantilever,
# Nearest to operating: tabernacles, greatest, conurbations, opposition, easily, producer, execute, underpinnings,
# Nearest to http: alberta, possessions, dismay, zcoa, cline, stimson, angering, drm,
# Nearest to ocean: soloists, uncertainties, gauntlets, cleaned, opulence, girlfriend, liberals, you,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9664 0.0592 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9139 0.0580 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8967 0.0580 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8784 0.0579 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8068 0.0580 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8236 0.0574 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8181 0.0580 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8142 0.0580 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8093 0.0582 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7829 0.0588 sec/batch
# Nearest to history: regulate, brennan, colony, spencer, alton, videos, drops, reason,
# Nearest to that: juba, fashions, problems, pray, candidates, sounds, commercially, practice,
# Nearest to has: atmosphere, pleaded, scraped, claude, jellicoe, pictures, museum, timescale,
# Nearest to seven: d, david, caesarea, republica, stuffing, ambiguously, panspermia, om,
# Nearest to other: mark, subtypes, repent, substantiate, floppies, accompaniment, burden, upload,
# Nearest to many: zarqawi, parker, cooperated, meant, classicists, struct, suppositions, asleep,
# Nearest to up: seaports, reminders, zinc, ehrlich, dur, procession, acquired, endogenous,
# Nearest to four: extension, presented, km, abensberg, hurt, malcolm, ramos, contour,
# Nearest to older: enciphered, emergency, severus, interestingly, occurred, seriously, affords, trace,
# Nearest to bill: bumblebee, monument, rated, coastal, drums, kashmir, liturgics, polished,
# Nearest to engine: ennobled, corps, workspace, guttural, baptismal, pulley, dealers, carotid,
# Nearest to test: armpit, obstetricians, vocabulary, venue, league, everything, binswanger, wladislaus,
# Nearest to egypt: private, rhotic, fold, superset, missing, austro, galton, greenfield,
# Nearest to operating: ensured, greatest, underpinnings, execute, tabernacles, announce, conurbations, pc,
# Nearest to http: alberta, possessions, dismay, cline, pounds, julian, stimson, nations,
# Nearest to ocean: soloists, uncertainties, reproducing, verdun, englishman, gauntlets, girlfriend, opulence,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7955 0.0601 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7663 0.0592 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7188 0.0595 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7006 0.0595 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7391 0.0593 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6934 0.0591 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7130 0.0591 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7516 0.0588 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6915 0.0575 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6624 0.0578 sec/batch
# Nearest to history: regulate, brennan, spencer, colony, alton, centralizing, submission, reason,
# Nearest to that: juba, fashions, problems, pray, separable, imposes, ideologies, scripture,
# Nearest to has: atmosphere, jellicoe, pictures, pleaded, scraped, fencing, emilia, timescale,
# Nearest to seven: d, two, david, stuffing, republica, caesarea, om, ambiguously,
# Nearest to other: substantiate, repent, erupts, mark, accompaniment, subtypes, floppies, burden,
# Nearest to many: zarqawi, parker, suppositions, hizballah, meant, rinks, cooperated, struct,
# Nearest to up: seaports, reminders, acquired, dur, ehrlich, zinc, guests, endogenous,
# Nearest to four: km, nine, extension, presented, ramos, hurt, physician, abensberg,
# Nearest to older: enciphered, severus, affords, interestingly, jihad, schacht, complied, linda,
# Nearest to bill: bumblebee, kashmir, monument, rated, drums, coastal, liturgics, harvey,
# Nearest to engine: ennobled, corps, workspace, pulley, guttural, baptismal, dealers, hangul,
# Nearest to test: armpit, obstetricians, vocabulary, venue, wladislaus, satchel, todd, league,
# Nearest to egypt: rhotic, austro, fold, private, greenfield, missing, fascinating, superset,
# Nearest to operating: pc, underpinnings, talbot, ensured, tabernacles, conurbations, circulate, execute,
# Nearest to http: alberta, possessions, cline, dismay, commandants, tricolour, myrdal, pauly,
# Nearest to ocean: soloists, reproducing, uncertainties, verdun, opulence, gauntlets, girlfriend, englishman,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6618 0.0581 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6683 0.0562 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5972 0.0591 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6337 0.0591 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6502 0.0587 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6507 0.0588 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6003 0.0433 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5491 0.0595 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5082 0.0587 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4878 0.0592 sec/batch
# Nearest to history: regulate, spencer, alton, centralizing, colony, brennan, reason, natives,
# Nearest to that: usurpers, problems, not, scripture, separable, case, imposes, pray,
# Nearest to has: atmosphere, jellicoe, scraped, pictures, emilia, shirts, subscriptions, pleaded,
# Nearest to seven: d, two, david, eight, richard, om, fran, stuffing,
# Nearest to other: substantiate, erupts, schizophrenic, subtypes, accompaniment, floppies, burden, sesame,
# Nearest to many: zarqawi, suppositions, meant, nominate, cooperated, hizballah, struct, classicists,
# Nearest to up: seaports, zinc, reminders, acquired, dur, ehrlich, guests, stays,
# Nearest to four: nine, km, ramos, abensberg, richard, charles, five, physician,
# Nearest to older: enciphered, affords, severus, schacht, interestingly, ther, jihad, bradshaw,
# Nearest to bill: kashmir, bumblebee, rated, monument, harvey, gesch, drums, liturgics,
# Nearest to engine: ennobled, workspace, pulley, corps, dealers, guttural, hangul, mordechai,
# Nearest to test: armpit, obstetricians, vocabulary, wladislaus, satchel, venue, binswanger, everything,
# Nearest to egypt: rhotic, austro, greenfield, fold, cantilever, fascinating, gheg, private,
# Nearest to operating: pc, conurbations, underpinnings, talbot, resisters, execute, ensured, circulate,
# Nearest to http: alberta, possessions, pauly, myrdal, com, tricolour, cline, commandants,
# Nearest to ocean: soloists, reproducing, gauntlets, verdun, uncertainties, opulence, girlfriend, linz,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5146 0.0602 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5153 0.0590 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4538 0.0594 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5146 0.0595 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4920 0.0588 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4888 0.0589 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4739 0.0589 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4196 0.0585 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4191 0.0589 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4190 0.0586 sec/batch
# Nearest to history: spencer, colony, alton, regulate, natives, brennan, centralizing, blacks,
# Nearest to that: separable, case, problems, usurpers, not, or, pray, fashions,
# Nearest to has: atmosphere, jellicoe, jeju, notifying, subscriptions, leftrightarrow, marred, scraped,
# Nearest to seven: david, om, two, d, cnts, drafted, pioneer, stuffing,
# Nearest to other: schizophrenic, floppies, erupts, subtypes, substantiate, accompaniment, burden, franziska,
# Nearest to many: zarqawi, suppositions, nominate, fold, cooperated, struct, meant, cha,
# Nearest to up: seaports, dur, reminders, acquired, zinc, zooming, ehrlich, kaddish,
# Nearest to four: km, nine, abensberg, ramos, xander, textiles, passenger, buchner,
# Nearest to older: enciphered, ther, affords, schacht, severus, weser, interestingly, bradshaw,
# Nearest to bill: harvey, bumblebee, gesch, belize, drums, kashmir, liturgics, rated,
# Nearest to engine: ennobled, pulley, workspace, corps, hangul, dealers, carotid, mordechai,
# Nearest to test: armpit, obstetricians, wladislaus, vocabulary, everything, satchel, dribble, venue,
# Nearest to egypt: rhotic, austro, greenfield, gheg, cantilever, fascinating, private, armenians,
# Nearest to operating: pc, execute, talbot, software, conurbations, ticketing, underpinnings, resisters,
# Nearest to http: alberta, com, www, pauly, org, possessions, myrdal, cline,
# Nearest to ocean: soloists, reproducing, gauntlets, verdun, coastline, scarves, linz, opulence,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4370 0.0601 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4045 0.0585 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4257 0.0589 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4052 0.0588 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4139 0.0588 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4540 0.0586 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3897 0.0589 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3901 0.0591 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4528 0.0588 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3639 0.0590 sec/batch
# Nearest to history: natives, spencer, alton, colony, regulate, cataloging, centralizing, presaging,
# Nearest to that: separable, usurpers, case, not, problems, prescribed, misleading, attributing,
# Nearest to has: atmosphere, jellicoe, scraped, subscriptions, notifying, accompanies, jeju, leftrightarrow,
# Nearest to seven: two, om, david, cnts, pioneer, eight, d, fran,
# Nearest to other: substantiate, schizophrenic, floppies, accompaniment, franziska, subtypes, erupts, parental,
# Nearest to many: zarqawi, suppositions, nominate, meant, struct, fold, cha, cooperated,
# Nearest to up: dur, zooming, seaports, guests, shoot, stays, kaddish, acquired,
# Nearest to four: nine, km, abensberg, ramos, xander, runways, zero, five,
# Nearest to older: enciphered, ther, affords, schacht, severus, weser, household, interestingly,
# Nearest to bill: harvey, bumblebee, drums, gesch, liturgics, monument, belize, kashmir,
# Nearest to engine: pulley, ennobled, workspace, hangul, ignition, corps, dealers, lb,
# Nearest to test: armpit, obstetricians, wladislaus, dribble, nozzles, speed, errors, striped,
# Nearest to egypt: austro, rhotic, greenfield, armenians, cantilever, gheg, private, fascinating,
# Nearest to operating: pc, execute, ticketing, conurbations, software, talbot, semiconductor, compiler,
# Nearest to http: com, org, www, alberta, pauly, external, edu, myrdal,
# Nearest to ocean: soloists, coastline, reproducing, verdun, gauntlets, scarves, hibernate, intelsat,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3662 0.0604 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4024 0.0588 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3394 0.0590 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3779 0.0591 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3771 0.0592 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3546 0.0587 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3859 0.0583 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3897 0.0582 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3320 0.0593 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3347 0.0594 sec/batch
# Nearest to history: natives, colony, alton, lucia, blacks, outreach, centralizing, spencer,
# Nearest to that: not, case, separable, usurpers, misleading, problems, power, scripture,
# Nearest to has: atmosphere, jellicoe, subscriptions, scraped, pleaded, notifying, marred, cantilever,
# Nearest to seven: two, om, eight, cnts, three, drafted, d, fran,
# Nearest to other: substantiate, franziska, schizophrenic, subtypes, genotype, erupts, burden, forwarded,
# Nearest to many: zarqawi, suppositions, nominate, institutions, cha, fold, threat, meant,
# Nearest to up: zooming, kaddish, guests, seaports, shoot, dur, acquired, assemblage,
# Nearest to four: nine, km, abensberg, five, zero, xander, two, ramos,
# Nearest to older: enciphered, ther, household, median, severus, weser, affords, males,
# Nearest to bill: harvey, drums, gesch, bumblebee, liturgics, mckenna, belize, roused,
# Nearest to engine: pulley, ennobled, ignition, hangul, workspace, corps, lb, dealers,
# Nearest to test: armpit, obstetricians, wladislaus, speed, dribble, satchel, nozzles, striped,
# Nearest to egypt: austro, greenfield, rhotic, armenians, gheg, sinai, cantilever, hadj,
# Nearest to operating: pc, execute, ticketing, conurbations, software, talbot, semiconductor, widebody,
# Nearest to http: org, com, www, edu, external, html, pauly, alberta,
# Nearest to ocean: soloists, coastline, verdun, southeast, reproducing, gauntlets, monsoon, intelsat,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3375 0.0607 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2840 0.0596 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3658 0.0590 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3986 0.0588 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3966 0.0582 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2716 0.0589 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3022 0.0588 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3399 0.0595 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2242 0.0594 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3039 0.0573 sec/batch
# Nearest to history: natives, external, colony, outreach, lucia, daro, alton, wace,
# Nearest to that: case, problems, not, separable, prescribed, usurpers, scripture, misleading,
# Nearest to has: scraped, afterglow, notifying, jellicoe, pictures, performing, atmosphere, accompanies,
# Nearest to seven: two, eight, d, three, fran, om, unpaved, pioneer,
# Nearest to other: subtypes, substantiate, schizophrenic, genotype, franziska, erupts, vaginal, bottleneck,
# Nearest to many: zarqawi, suppositions, nominate, institutions, hizballah, rinks, fold, meant,
# Nearest to up: kaddish, guests, shoot, zooming, acquired, seaports, legislating, assemblage,
# Nearest to four: nine, two, five, zero, km, abensberg, xander, one,
# Nearest to older: enciphered, household, ther, median, weser, affords, severus, males,
# Nearest to bill: harvey, gesch, bumblebee, roused, drums, rated, mckenna, dray,
# Nearest to engine: pulley, ignition, hangul, ennobled, workspace, corps, dealers, tutorials,
# Nearest to test: armpit, obstetricians, speed, dribble, wladislaus, nozzles, satchel, gebhard,
# Nearest to egypt: greenfield, austro, armenians, rhotic, gheg, caliphate, sinai, hadj,
# Nearest to operating: pc, execute, ticketing, software, compiler, solaris, semiconductor, laptop,
# Nearest to http: www, org, com, edu, html, pauly, external, tricolour,
# Nearest to ocean: soloists, verdun, archipelago, coastline, gauntlets, southeast, intelsat, monsoon,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3286 0.0596 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3265 0.0567 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3068 0.0266 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2527 0.0590 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2110 0.0592 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1938 0.0589 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2278 0.0586 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2367 0.0590 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2248 0.0591 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1935 0.0594 sec/batch
# Nearest to history: external, natives, daro, outreach, presaging, encyclopedia, cryptographers, forums,
# Nearest to that: usurpers, separable, case, yet, pray, prescribed, misleading, not,
# Nearest to has: jellicoe, name, jeju, pictures, notifying, marred, afterglow, performing,
# Nearest to seven: two, eight, three, fran, om, cnts, d, unpaved,
# Nearest to other: franziska, schizophrenic, subtypes, genotype, substantiate, cutaways, floppies, catholic,
# Nearest to many: zarqawi, suppositions, nominate, cha, institutions, hizballah, fold, rinks,
# Nearest to up: guests, shoot, kaddish, zooming, acquired, assemblage, seaports, reminders,
# Nearest to four: nine, km, xander, two, zero, five, abensberg, six,
# Nearest to older: enciphered, household, median, ther, males, weser, age, affords,
# Nearest to bill: harvey, gesch, bumblebee, mckenna, roused, drums, liturgics, hummingbird,
# Nearest to engine: pulley, hangul, ignition, ennobled, workspace, corps, dealers, lb,
# Nearest to test: armpit, obstetricians, speed, nozzles, lm, satchel, wladislaus, dribble,
# Nearest to egypt: armenians, greenfield, gheg, caliphate, austro, sinai, rhotic, volcanoes,
# Nearest to operating: pc, execute, ticketing, laptop, architectures, compiler, solaris, semiconductor,
# Nearest to http: www, org, com, edu, html, pauly, external, htm,
# Nearest to ocean: soloists, archipelago, verdun, coastline, gauntlets, intelsat, monsoon, southeast,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2631 0.0600 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2164 0.0589 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2357 0.0592 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1422 0.0592 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1549 0.0591 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1773 0.0591 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1524 0.0591 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1873 0.0595 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2009 0.0593 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1573 0.0591 sec/batch
# Nearest to history: external, natives, cataloging, outreach, lucia, forums, daro, brindle,
# Nearest to that: separable, prescribed, not, usurpers, yet, case, scripture, misleading,
# Nearest to has: name, afterglow, notifying, cantilever, scraped, accompanies, marred, performing,
# Nearest to seven: two, om, eight, three, unpaved, cnts, pioneer, fran,
# Nearest to other: franziska, catholic, schizophrenic, floppies, subtypes, parental, raw, forwarded,
# Nearest to many: zarqawi, suppositions, cha, institutions, nominate, fold, asleep, squat,
# Nearest to up: shoot, zooming, kaddish, guests, hitting, acquired, seaports, assemblage,
# Nearest to four: km, two, nine, zero, xander, five, abensberg, six,
# Nearest to older: enciphered, household, median, males, age, ther, family, householder,
# Nearest to bill: harvey, gesch, mckenna, bumblebee, drums, rated, hummingbird, roused,
# Nearest to engine: pulley, ignition, hangul, workspace, corps, lb, dealers, ennobled,
# Nearest to test: armpit, speed, obstetricians, nozzles, lm, satchel, dribble, wladislaus,
# Nearest to egypt: greenfield, armenians, caliphate, gheg, sinai, austro, rhotic, volcanoes,
# Nearest to operating: pc, execute, pdp, ticketing, laptop, dos, compiler, architectures,
# Nearest to http: www, org, edu, com, html, external, htm, pauly,
# Nearest to ocean: soloists, archipelago, verdun, gauntlets, coastline, intelsat, hibernate, climatic,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1885 0.0604 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2465 0.0586 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1676 0.0589 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1480 0.0584 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1582 0.0590 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2004 0.0590 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2046 0.0590 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1847 0.0582 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1255 0.0580 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1799 0.0585 sec/batch
# Nearest to history: external, natives, lucia, cataloging, daro, outreach, forums, homepage,
# Nearest to that: usurpers, not, misleading, separable, pray, yet, scripture, prescribed,
# Nearest to has: afterglow, name, marred, performing, cantilever, scraped, subscriptions, accompanies,
# Nearest to seven: two, eight, three, four, om, zero, six, fran,
# Nearest to other: schizophrenic, catholic, floppies, subtypes, parental, genotype, cutaways, forwarded,
# Nearest to many: zarqawi, suppositions, cha, nominate, institutions, asleep, hizballah, nightclubs,
# Nearest to up: shoot, kaddish, guests, zooming, acquired, sudeten, hitting, legislating,
# Nearest to four: two, zero, nine, five, xander, km, six, abensberg,
# Nearest to older: enciphered, household, median, ther, males, age, family, weser,
# Nearest to bill: harvey, gesch, bumblebee, drums, visage, mckenna, hummingbird, rated,
# Nearest to engine: pulley, ignition, hangul, workspace, lb, corps, ennobled, dealers,
# Nearest to test: armpit, nozzles, obstetricians, lm, speed, dribble, satchel, wladislaus,
# Nearest to egypt: greenfield, armenians, caliphate, gheg, sinai, austro, rhotic, governorate,
# Nearest to operating: execute, pc, pdp, ticketing, solaris, compiler, dos, widebody,
# Nearest to http: www, org, edu, com, html, htm, shtml, external,
# Nearest to ocean: archipelago, verdun, soloists, intelsat, radiotelephone, coastline, gauntlets, dredging,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1961 0.0602 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1830 0.0584 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1639 0.0593 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2028 0.0593 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1560 0.0589 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1219 0.0590 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1808 0.0593 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1133 0.0590 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1747 0.0596 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1869 0.0596 sec/batch
# Nearest to history: external, natives, lucia, daro, outreach, homepage, encyclopedia, ancient,
# Nearest to that: usurpers, pray, yet, not, misleading, attributing, illustrious, occurred,
# Nearest to has: afterglow, cantilever, rado, marred, name, judean, alternative, performing,
# Nearest to seven: two, three, eight, four, six, one, zero, fran,
# Nearest to other: catholic, schizophrenic, substantiate, parental, subtypes, cutaways, genotype, franziska,
# Nearest to many: zarqawi, institutions, suppositions, cha, nominate, meant, asleep, rhetorician,
# Nearest to up: kaddish, shoot, zooming, guests, acquired, assemblage, machinima, bluesy,
# Nearest to four: two, five, zero, nine, six, one, xander, three,
# Nearest to older: enciphered, household, median, ther, family, males, age, weser,
# Nearest to bill: harvey, gesch, bumblebee, referendum, visage, appointees, petition, roused,
# Nearest to engine: pulley, ignition, engines, hangul, workspace, lb, ennobled, corps,
# Nearest to test: armpit, nozzles, obstetricians, lm, speed, wladislaus, satchel, tav,
# Nearest to egypt: greenfield, armenians, sinai, governorate, caliphate, gheg, partition, phrygia,
# Nearest to operating: execute, pc, ticketing, pdp, laptop, solaris, conurbations, widebody,
# Nearest to http: www, org, edu, com, html, htm, shtml, pauly,
# Nearest to ocean: verdun, archipelago, soloists, dredging, radiotelephone, geographical, intelsat, gauntlets,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2121 0.0604 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1422 0.0588 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1425 0.0593 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1432 0.0589 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0458 0.0591 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1636 0.0592 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1364 0.0589 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1349 0.0593 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1456 0.0118 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1053 0.0594 sec/batch
# Nearest to history: external, natives, cataloging, homepage, outreach, daro, lucia, ancient,
# Nearest to that: not, some, misleading, separable, yet, attributing, case, problems,
# Nearest to has: afterglow, name, performing, marred, cantilever, alternative, accompanies, judean,
# Nearest to seven: two, three, eight, four, zero, six, one, unpaved,
# Nearest to other: desktop, subtypes, schizophrenic, cutaways, parental, boric, substantiate, franziska,
# Nearest to many: zarqawi, cha, suppositions, institutions, nominate, and, hizballah, tragedies,
# Nearest to up: zooming, shoot, kaddish, guests, acquired, ramps, stays, bluesy,
# Nearest to four: two, zero, nine, five, six, one, xander, three,
# Nearest to older: enciphered, household, median, males, ther, family, age, weser,
# Nearest to bill: harvey, bumblebee, gesch, referendum, eldridge, visage, tam, appointees,
# Nearest to engine: pulley, ignition, engines, hangul, workspace, lb, corps, ennobled,
# Nearest to test: armpit, lm, nozzles, obstetricians, speed, dosage, flybys, gebhard,
# Nearest to egypt: greenfield, sinai, armenians, caliphate, gheg, governorate, volcanoes, rhotic,
# Nearest to operating: execute, pc, pdp, ticketing, laptop, solaris, dos, conurbations,
# Nearest to http: www, org, edu, com, html, htm, shtml, pauly,
# Nearest to ocean: verdun, soloists, archipelago, dredging, radiotelephone, intelsat, gauntlets, geographical,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0608 0.0586 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0427 0.0588 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0708 0.0563 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0571 0.0566 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0856 0.0588 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0397 0.0591 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0842 0.0591 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0849 0.0591 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1288 0.0592 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0284 0.0588 sec/batch
# Nearest to history: external, daro, natives, homepage, lucia, ancient, heritage, scandinavians,
# Nearest to that: usurpers, some, separable, misleading, pray, yet, not, case,
# Nearest to has: afterglow, name, cantilever, performing, marred, judean, with, accompanies,
# Nearest to seven: three, two, four, eight, zero, six, eca, elena,
# Nearest to other: catholic, franziska, schizophrenic, subtypes, cutaways, forwarded, parental, romanians,
# Nearest to many: zarqawi, cha, suppositions, and, nominate, institutions, hizballah, meant,
# Nearest to up: shoot, zooming, kaddish, guests, caught, machinima, stays, hitting,
# Nearest to four: two, zero, five, nine, six, three, one, xander,
# Nearest to older: household, enciphered, median, age, males, family, householder, ther,
# Nearest to bill: bumblebee, tam, harvey, hummingbird, ken, quarterfinal, gamespy, eldridge,
# Nearest to engine: pulley, ignition, hangul, engines, workspace, lb, ennobled, corps,
# Nearest to test: lm, armpit, nozzles, obstetricians, speed, satchel, wickets, flybys,
# Nearest to egypt: greenfield, sinai, gheg, caliphate, armenians, volcanoes, governorate, rhotic,
# Nearest to operating: execute, pc, pdp, ticketing, solaris, conurbations, dos, widebody,
# Nearest to http: www, org, edu, com, html, htm, shtml, pauly,
# Nearest to ocean: archipelago, verdun, radiotelephone, intelsat, soloists, dredging, scarves, gauntlets,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0438 0.0605 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0041 0.0592 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0139 0.0588 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0479 0.0591 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0863 0.0592 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0550 0.0591 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0537 0.0593 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0922 0.0589 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0419 0.0591 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0425 0.0592 sec/batch
# Nearest to history: external, homepage, cataloging, daro, natives, forums, ancient, outreach,
# Nearest to that: separable, misleading, not, case, for, some, yet, or,
# Nearest to has: afterglow, name, cantilever, marred, reactants, pdl, alternative, judean,
# Nearest to seven: three, four, two, eight, six, zero, five, nine,
# Nearest to other: catholic, schizophrenic, franziska, substantiate, parental, cutaways, genotype, forwarded,
# Nearest to many: zarqawi, and, suppositions, institutions, cha, meant, nominate, hizballah,
# Nearest to up: shoot, zooming, kaddish, guests, machinima, ramps, sudeten, caught,
# Nearest to four: two, zero, five, nine, six, three, one, seven,
# Nearest to older: household, enciphered, median, age, males, family, householder, ther,
# Nearest to bill: bumblebee, drums, harvey, ken, tam, quarterfinal, referendum, gamespy,
# Nearest to engine: pulley, ignition, engines, workspace, hangul, lb, ennobled, corps,
# Nearest to test: lm, armpit, nozzles, obstetricians, speed, expected, dosage, bioterrorism,
# Nearest to egypt: greenfield, gheg, sinai, volcanoes, armenians, governorate, hadj, caliphate,
# Nearest to operating: execute, pdp, pc, ticketing, dos, widebody, compiler, solaris,
# Nearest to http: www, org, edu, com, html, htm, shtml, pauly,
# Nearest to ocean: radiotelephone, verdun, archipelago, intelsat, dredging, soloists, scarves, geographical,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0644 0.0604 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0629 0.0592 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0757 0.0594 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0219 0.0590 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0891 0.0589 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0442 0.0588 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0579 0.0594 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0545 0.0593 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0482 0.0589 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0666 0.0588 sec/batch
# Nearest to history: external, daro, natives, ancient, homepage, lucia, western, scandinavians,
# Nearest to that: usurpers, separable, misleading, pray, yet, some, attributing, not,
# Nearest to has: afterglow, name, marred, cantilever, routinely, with, pdl, controllable,
# Nearest to seven: three, two, four, eight, six, zero, five, one,
# Nearest to other: catholic, franziska, romanians, parental, substantiate, schizophrenic, subtypes, cutaways,
# Nearest to many: zarqawi, and, cha, institutions, sinhalese, suppositions, nominate, hizballah,
# Nearest to up: shoot, zooming, kaddish, guests, ramps, sudeten, acquired, seaports,
# Nearest to four: two, zero, five, nine, three, six, one, seven,
# Nearest to older: household, median, enciphered, age, males, family, females, householder,
# Nearest to bill: referendum, tam, petition, bumblebee, appointees, drums, harvey, visage,
# Nearest to engine: pulley, ignition, engines, workspace, hangul, ennobled, lb, corps,
# Nearest to test: lm, armpit, nozzles, obstetricians, flybys, dosage, expected, wickets,
# Nearest to egypt: greenfield, sinai, gheg, armenians, caliphate, volcanoes, governorate, partition,
# Nearest to operating: execute, pdp, pc, dos, ticketing, widebody, solaris, compiler,
# Nearest to http: www, org, edu, com, htm, html, shtml, pauly,
# Nearest to ocean: radiotelephone, verdun, archipelago, intelsat, dredging, soloists, tropospheric, geographical,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0437 0.0605 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9921 0.0592 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0477 0.0593 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0513 0.0594 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0611 0.0595 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1256 0.0593 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1309 0.0592 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0253 0.0594 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0480 0.0593 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0396 0.0591 sec/batch
# Nearest to history: external, daro, homepage, natives, ancient, cataloging, links, pune,
# Nearest to that: separable, case, misleading, not, pray, yet, culpability, implied,
# Nearest to has: afterglow, with, name, pdl, controllable, is, cantilever, an,
# Nearest to seven: three, two, four, eight, six, zero, one, five,
# Nearest to other: franziska, boric, catholic, romanians, subtypes, cutaways, reis, reactors,
# Nearest to many: zarqawi, and, institutions, cha, hizballah, nominate, tragedies, meant,
# Nearest to up: zooming, shoot, guests, kaddish, ramps, suburban, zeng, caught,
# Nearest to four: two, zero, five, nine, six, three, one, seven,
# Nearest to older: household, median, enciphered, family, males, age, females, householder,
# Nearest to bill: referendum, appointees, bumblebee, tam, eldridge, petition, drums, harvey,
# Nearest to engine: pulley, ignition, engines, workspace, hangul, ennobled, lb, cylinder,
# Nearest to test: lm, armpit, nozzles, dosage, obstetricians, flybys, wickets, tests,
# Nearest to egypt: greenfield, gheg, armenians, governorate, sinai, caliphate, volcanoes, hadj,
# Nearest to operating: pdp, execute, pc, ticketing, widebody, solaris, dos, compiler,
# Nearest to http: www, org, edu, com, htm, html, shtml, pauly,
# Nearest to ocean: radiotelephone, archipelago, verdun, dredging, intelsat, tropospheric, airstrip, soloists,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9560 0.0605 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0241 0.0595 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0345 0.0593 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0243 0.0594 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0806 0.0594 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0508 0.0546 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0209 0.0593 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9680 0.0590 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0296 0.0590 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9668 0.0589 sec/batch
# Nearest to history: external, daro, homepage, ancient, cataloging, autocracy, natives, pune,
# Nearest to that: pray, not, some, yet, someone, usurpers, misleading, wakes,
# Nearest to has: afterglow, is, an, reactants, controllable, pdl, name, cantilever,
# Nearest to seven: three, two, four, eight, zero, six, one, five,
# Nearest to other: franziska, catholic, romanians, subtypes, parental, cutaways, boric, schizophrenic,
# Nearest to many: zarqawi, and, institutions, cha, harmonious, leena, nominate, early,
# Nearest to up: zooming, shoot, kaddish, guests, ramps, elbows, tcs, reminders,
# Nearest to four: two, zero, five, nine, three, six, one, seven,
# Nearest to older: household, median, family, enciphered, age, males, females, householder,
# Nearest to bill: referendum, bumblebee, eldridge, tam, appointees, drums, wasserman, quarterfinal,
# Nearest to engine: pulley, ignition, engines, workspace, cylinder, hangul, ennobled, mach,
# Nearest to test: lm, wickets, obstetricians, tests, dosage, nozzles, armpit, flybys,
# Nearest to egypt: gheg, greenfield, sinai, caliphate, governorate, armenians, adh, volcanoes,
# Nearest to operating: pdp, pc, execute, dos, ticketing, wads, widebody, solaris,
# Nearest to http: www, org, edu, com, html, htm, shtml, pauly,
# Nearest to ocean: radiotelephone, verdun, uncertainties, archipelago, dredging, tropospheric, transeau, girlfriend,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9747 0.0604 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9362 0.0574 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9715 0.0581 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0068 0.0564 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0085 0.0584 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0071 0.0589 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9271 0.0592 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9512 0.0595 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9153 0.0591 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9790 0.0596 sec/batch
# Nearest to history: external, daro, ancient, cataloging, homepage, pune, novgorod, links,
# Nearest to that: not, case, separable, pray, misleading, usurpers, some, culpability,
# Nearest to has: with, afterglow, an, is, as, reactants, judean, pdl,
# Nearest to seven: three, two, four, zero, eight, six, five, one,
# Nearest to other: catholic, franziska, parental, boric, forwarded, romanians, schizophrenic, vaginal,
# Nearest to many: zarqawi, and, cha, institutions, leena, tragedies, harmonious, early,
# Nearest to up: shoot, zooming, guests, kaddish, elbows, ramps, tcs, caught,
# Nearest to four: two, zero, five, three, nine, six, one, seven,
# Nearest to older: household, median, age, family, males, females, enciphered, householder,
# Nearest to bill: referendum, bumblebee, tam, eldridge, quarterfinal, crawl, hummingbird, appointees,
# Nearest to engine: pulley, ignition, engines, workspace, cylinder, mach, hangul, ennobled,
# Nearest to test: lm, tests, wickets, dosage, nozzles, obstetricians, armpit, cricket,
# Nearest to egypt: sinai, gheg, greenfield, governorate, armenians, adh, caliphate, volcanoes,
# Nearest to operating: execute, pdp, ticketing, pc, widebody, dos, wads, conurbations,
# Nearest to http: www, org, edu, com, html, htm, shtml, pauly,
# Nearest to ocean: radiotelephone, archipelago, verdun, uncertainties, tropospheric, saarc, arabian, soloists,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0152 0.0607 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0070 0.0596 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9822 0.0593 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9933 0.0594 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0456 0.0595 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9018 0.0593 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0038 0.0596 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0015 0.0599 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9754 0.0590 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9757 0.0594 sec/batch
# Nearest to history: external, daro, homepage, cataloging, links, pune, ancient, brindle,
# Nearest to that: not, misleading, case, yet, separable, culpability, pray, usurpers,
# Nearest to has: with, afterglow, an, is, pdl, routinely, as, reactants,
# Nearest to seven: three, four, two, eight, six, one, zero, nine,
# Nearest to other: catholic, franziska, parental, putin, cutaways, schizophrenic, accompaniment, boric,
# Nearest to many: zarqawi, and, cha, tragedies, meant, leena, institutions, harmonious,
# Nearest to up: shoot, zooming, guests, kaddish, ramps, elbows, bluesy, sudeten,
# Nearest to four: two, zero, five, three, nine, six, one, seven,
# Nearest to older: household, median, age, males, family, enciphered, females, householder,
# Nearest to bill: referendum, bumblebee, tam, appointees, eldridge, crawl, drums, quarterfinal,
# Nearest to engine: pulley, ignition, engines, workspace, ennobled, cylinder, hangul, mach,
# Nearest to test: lm, tests, obstetricians, dosage, wickets, nozzles, disappear, armpit,
# Nearest to egypt: sinai, greenfield, governorate, gheg, armenians, adh, hadj, slay,
# Nearest to operating: execute, pc, pdp, ticketing, dos, widebody, wads, nextstep,
# Nearest to http: www, org, edu, com, htm, html, shtml, pauly,
# Nearest to ocean: radiotelephone, archipelago, tropospheric, verdun, uncertainties, saarc, arabian, airstrip,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9837 0.0608 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9705 0.0591 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0033 0.0592 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0006 0.0593 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9970 0.0593 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0115 0.0592 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9767 0.0596 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9406 0.0593 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9710 0.0590 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0199 0.0591 sec/batch
# Nearest to history: external, daro, ancient, homepage, links, pune, journal, novgorod,
# Nearest to that: not, case, usurpers, misleading, culpability, some, pray, separable,
# Nearest to has: with, is, an, afterglow, as, this, pdl, routinely,
# Nearest to seven: three, four, two, eight, six, five, one, zero,
# Nearest to other: catholic, franziska, parental, boric, putin, vaginal, romanians, cutaways,
# Nearest to many: zarqawi, and, cha, tragedies, szlachta, meant, institutions, harmonious,
# Nearest to up: zooming, shoot, ramps, guests, kaddish, sudeten, tcs, bluesy,
# Nearest to four: two, five, zero, three, six, nine, one, seven,
# Nearest to older: household, median, age, family, males, enciphered, females, householder,
# Nearest to bill: referendum, appointees, tam, petition, bumblebee, adequate, fiefdom, monument,
# Nearest to engine: pulley, ignition, engines, workspace, ennobled, cylinder, mach, sadi,
# Nearest to test: tests, lm, wickets, dosage, obstetricians, armpit, nozzles, disappear,
# Nearest to egypt: sinai, greenfield, gheg, governorate, hadj, adh, slay, cairo,
# Nearest to operating: pc, execute, widebody, pdp, ticketing, wads, dos, opposition,
# Nearest to http: www, org, edu, com, htm, html, shtml, pauly,
# Nearest to ocean: radiotelephone, archipelago, uncertainties, verdun, tropospheric, arabian, airstrip, islands,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9800 0.0606 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0802 0.0592 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0330 0.0590 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0327 0.0590 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9308 0.0588 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9258 0.0592 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9538 0.0590 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9223 0.0594 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9921 0.0594 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9802 0.0592 sec/batch
# Nearest to history: external, daro, homepage, links, ancient, pune, journal, cataloging,
# Nearest to that: case, not, some, yet, encoder, misleading, separable, remuneration,
# Nearest to has: with, an, is, afterglow, as, cantilever, pdl, name,
# Nearest to seven: three, four, two, eight, one, six, five, nine,
# ...
# Nearest to operating: dos, widebody, consolidate, pdp, ticketing, threatened, oses, idl,
# Nearest to http: www, org, edu, htm, html, shtml, com, ments,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, arabian, dredging, verdun, atlantic, eutelsat,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8689 0.0605 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7368 0.0593 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8439 0.0589 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7953 0.0591 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8249 0.0592 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8268 0.0593 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8180 0.0593 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8238 0.0593 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8435 0.0595 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9192 0.0591 sec/batch
# Nearest to history: links, external, daro, journal, ancient, simulation, timeline, database,
# Nearest to that: not, have, which, some, for, a, yet, as,
# Nearest to has: is, with, an, as, it, a, only, s,
# Nearest to seven: three, four, one, six, two, five, nine, eight,
# Nearest to other: and, catholic, of, the, are, as, each, who,
# Nearest to many: are, and, most, in, zarqawi, well, as, but,
# Nearest to up: shoot, zooming, ramps, a, lonely, proud, kaddish, plus,
# Nearest to four: three, two, zero, five, six, one, nine, seven,
# Nearest to older: age, household, median, family, females, families, households, males,
# Nearest to bill: bumblebee, shipped, graham, monument, appointees, charter, canis, fiefdom,
# Nearest to engine: pulley, ennobled, ignition, deja, engines, workspace, mondial, awd,
# Nearest to test: tests, wickets, dosage, cricket, freeland, viking, testing, vocabulary,
# Nearest to egypt: almoravid, giza, westerner, adh, sharm, cairo, slay, songwriting,
# Nearest to operating: dos, widebody, idl, consolidate, pdp, threatened, wads, nextstep,
# Nearest to http: www, org, edu, htm, html, shtml, com, ments,
# Nearest to ocean: radiotelephone, tropospheric, airstrip, eutelsat, dredging, arabian, atlantic, verdun,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8463 0.0603 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8649 0.0590 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8291 0.0588 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8666 0.0588 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8288 0.0569 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8639 0.0587 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8425 0.0573 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8569 0.0578 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8672 0.0593 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8487 0.0589 sec/batch
# Nearest to history: links, ancient, external, daro, journal, timeline, see, founded,
# Nearest to that: have, not, some, which, yet, a, it, come,
# Nearest to has: is, an, with, a, as, it, only, s,
# Nearest to seven: three, four, one, two, six, nine, five, eight,
# Nearest to other: and, the, catholic, as, of, who, are, most,
# Nearest to many: and, are, most, zarqawi, well, in, their, as,
# Nearest to up: lonely, proud, shoot, a, zooming, ramps, devour, kaddish,
# Nearest to four: three, two, six, zero, one, five, nine, seven,
# Nearest to older: age, median, family, household, females, families, households, males,
# Nearest to bill: bumblebee, monument, shipped, graham, appointees, adequate, liberties, referendum,
# Nearest to engine: deja, ennobled, mondial, caps, pulley, workspace, ignition, hanson,
# Nearest to test: tests, wickets, cricket, dosage, freeland, vocabulary, england, kershaw,
# Nearest to egypt: giza, almoravid, cairo, sharm, westerner, nile, songwriting, egyptian,
# Nearest to operating: dos, widebody, idl, consolidate, threatened, pdp, inquire, ticketing,
# Nearest to http: www, org, edu, htm, html, com, shtml, gov,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, eutelsat, dredging, atlantic, microwave, verdun,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8803 0.0605 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8443 0.0589 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8014 0.0588 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8110 0.0591 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8910 0.0595 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8329 0.0594 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9595 0.0591 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8711 0.0586 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9188 0.0589 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8218 0.0588 sec/batch
# Nearest to history: links, external, ancient, journal, daro, timeline, of, database,
# Nearest to that: have, not, which, some, yet, a, come, it,
# Nearest to has: is, with, a, an, as, it, s, only,
# Nearest to seven: three, one, four, two, six, five, eight, nine,
# Nearest to other: and, of, catholic, as, who, are, the, most,
# Nearest to many: and, are, most, zarqawi, in, well, their, as,
# Nearest to up: lonely, proud, camulodunum, with, guests, judges, ramps, kirkcaldy,
# Nearest to four: three, two, zero, six, five, one, nine, seven,
# Nearest to older: family, median, household, age, families, females, households, males,
# Nearest to bill: bumblebee, monument, graham, appointees, shipped, adequate, charter, liberties,
# Nearest to engine: deja, ennobled, ignition, hanson, pulley, mondial, caps, fick,
# Nearest to test: tests, wickets, cricket, dosage, freeland, vocabulary, england, testing,
# Nearest to egypt: giza, almoravid, cairo, sharm, egyptian, westerner, songwriting, nile,
# Nearest to operating: dos, idl, widebody, consolidate, threatened, inquire, pdp, ticketing,
# Nearest to http: www, org, edu, htm, html, shtml, com, gov,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, eutelsat, atlantic, dredging, arabian, verdun,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7902 0.0598 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8778 0.0589 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7674 0.0588 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8722 0.0587 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8107 0.0589 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8482 0.0586 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8811 0.0337 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8145 0.0586 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8401 0.0588 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8263 0.0591 sec/batch
# Nearest to history: links, external, ancient, daro, journal, timeline, of, dol,
# Nearest to that: have, not, some, a, which, come, it, to,
# Nearest to has: is, with, an, as, a, it, s, since,
# Nearest to seven: three, one, four, two, six, five, nine, eight,
# Nearest to other: are, and, of, as, the, each, who, catholic,
# Nearest to many: are, most, and, zarqawi, well, in, as, tragedies,
# Nearest to up: lonely, with, proud, kirkcaldy, amd, kaddish, devour, ramps,
# Nearest to four: three, two, one, six, zero, five, nine, seven,
# Nearest to older: family, median, age, household, families, females, households, householder,
# Nearest to bill: bumblebee, graham, appointees, shipped, monument, adequate, giving, charter,
# Nearest to engine: deja, ennobled, ignition, workspace, hanson, caps, mondial, tutorials,
# Nearest to test: tests, wickets, cricket, dosage, freeland, england, viking, testing,
# Nearest to egypt: giza, cairo, almoravid, nile, sharm, westerner, adh, songwriting,
# Nearest to operating: dos, widebody, wads, idl, nextstep, pdp, pc, consolidate,
# Nearest to http: www, org, edu, htm, html, shtml, com, ments,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, dredging, eutelsat, atlantic, arabian, rook,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8135 0.0600 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8079 0.0589 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8247 0.0591 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8136 0.0591 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8791 0.0590 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8314 0.0596 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8682 0.0592 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7553 0.0588 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7963 0.0590 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7750 0.0593 sec/batch
# Nearest to history: links, external, ancient, daro, journal, timeline, of, founded,
# Nearest to that: not, which, have, it, a, as, some, for,
# Nearest to has: is, an, with, it, as, a, only, s,
# Nearest to seven: three, four, one, two, six, eight, five, nine,
# Nearest to other: and, are, of, the, as, each, most, catholic,
# Nearest to many: are, and, most, in, well, zarqawi, as, but,
# Nearest to up: lonely, devour, with, kaddish, kirkcaldy, amd, babe, ramps,
# Nearest to four: three, two, six, zero, one, five, seven, nine,
# Nearest to older: median, household, age, family, families, females, households, householder,
# Nearest to bill: bumblebee, shipped, charter, graham, monument, appointees, adequate, conjured,
# Nearest to engine: deja, ennobled, pulley, mondial, caps, ignition, hanson, workspace,
# Nearest to test: tests, wickets, cricket, dosage, freeland, england, viking, vocabulary,
# Nearest to egypt: giza, cairo, almoravid, sharm, nile, westerner, egyptian, adh,
# Nearest to operating: dos, pdp, widebody, idl, threatened, nextstep, wads, ticketing,
# Nearest to http: www, org, edu, htm, html, shtml, com, ments,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, eutelsat, atlantic, dredging, channels, coaxial,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7511 0.0602 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7874 0.0587 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8468 0.0590 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8163 0.0589 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8313 0.0592 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9128 0.0593 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8411 0.0588 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8135 0.0588 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8196 0.0587 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8508 0.0588 sec/batch
# Nearest to history: links, external, ancient, journal, of, database, daro, timeline,
# Nearest to that: have, not, which, some, a, as, this, it,
# Nearest to has: is, an, with, it, as, a, only, s,
# Nearest to seven: three, one, four, six, two, eight, nine, five,
# Nearest to other: and, the, are, of, most, catholic, as, each,
# Nearest to many: are, most, and, in, well, zarqawi, as, have,
# Nearest to up: lonely, kaddish, proud, with, kirkcaldy, devour, amd, babe,
# Nearest to four: two, three, six, one, zero, five, seven, eight,
# Nearest to older: household, age, family, median, families, females, households, eight,
# Nearest to bill: bumblebee, charter, graham, shipped, appointees, monument, giving, adequate,
# Nearest to engine: deja, ignition, pulley, ennobled, caps, mondial, workspace, engines,
# Nearest to test: tests, wickets, cricket, dosage, freeland, vocabulary, relating, testing,
# Nearest to egypt: giza, cairo, sharm, egyptian, westerner, almoravid, nile, adh,
# Nearest to operating: dos, threatened, widebody, idl, pdp, nextstep, wads, inquire,
# Nearest to http: www, org, htm, edu, shtml, html, com, gov,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, eutelsat, atlantic, arabian, channels, dredging,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8574 0.0599 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8358 0.0590 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7620 0.0591 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8351 0.0593 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8653 0.0591 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8364 0.0582 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8147 0.0592 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8426 0.0590 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7656 0.0588 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8232 0.0586 sec/batch
# Nearest to history: links, ancient, external, of, journal, see, timeline, founded,
# Nearest to that: have, not, which, some, a, to, it, as,
# Nearest to has: is, an, with, as, a, it, since, only,
# Nearest to seven: three, four, one, six, two, eight, nine, five,
# Nearest to other: and, the, of, are, as, most, each, who,
# Nearest to many: are, and, most, in, well, as, zarqawi, however,
# Nearest to up: lonely, amd, kaddish, with, devour, kirkcaldy, zooming, caravans,
# Nearest to four: three, two, six, one, five, zero, seven, eight,
# Nearest to older: household, family, median, age, families, eight, females, households,
# Nearest to bill: charter, graham, giving, monument, appointees, bumblebee, shipped, adequate,
# Nearest to engine: deja, ignition, ennobled, pulley, caps, engines, mondial, tutorials,
# Nearest to test: tests, wickets, cricket, dosage, freeland, england, vocabulary, relating,
# Nearest to egypt: giza, cairo, almoravid, sharm, egyptian, nile, songwriting, westerner,
# Nearest to operating: dos, widebody, threatened, idl, pdp, wads, nextstep, ticketing,
# Nearest to http: www, org, htm, edu, shtml, html, com, gov,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, eutelsat, atlantic, earth, dredging, chagos,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8559 0.0600 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7998 0.0591 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9083 0.0591 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9116 0.0594 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8744 0.0592 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8083 0.0591 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7781 0.0588 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8288 0.0590 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7066 0.0588 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8422 0.0589 sec/batch
# Nearest to history: links, ancient, external, of, journal, timeline, see, times,
# Nearest to that: have, which, a, not, some, to, this, it,
# Nearest to has: a, an, is, with, as, it, s, only,
# Nearest to seven: one, three, four, six, two, nine, five, eight,
# Nearest to other: and, the, of, are, most, as, each, such,
# Nearest to many: are, most, and, well, in, zarqawi, as, however,
# Nearest to up: lonely, with, amd, a, devour, kirkcaldy, kaddish, tcs,
# Nearest to four: two, three, six, one, five, zero, seven, nine,
# Nearest to older: family, median, household, age, families, households, females, householder,
# Nearest to bill: graham, charter, monument, appointees, bumblebee, shipped, giving, conjured,
# Nearest to engine: deja, caps, ignition, ennobled, pulley, tutorials, engines, dusting,
# Nearest to test: tests, wickets, cricket, dosage, freeland, england, relating, captains,
# Nearest to egypt: giza, almoravid, cairo, sharm, westerner, songwriting, egyptian, nile,
# Nearest to operating: dos, widebody, threatened, pdp, ticketing, idl, paucity, wads,
# Nearest to http: www, org, htm, edu, shtml, html, com, ments,
# Nearest to ocean: tropospheric, radiotelephone, airstrip, eutelsat, atlantic, dredging, arabian, scarves,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8205 0.0605 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8211 0.0590 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
